# %% [markdown]
# # Per-Chapter Drills
#
# A simpler, non-randomized version of `mock_interview.ipynb` for focused review of **one
# chapter at a time** — every question in that chapter, in a fixed order, no sampling, no
# branching. Use this after finishing a chapter, or the week before an interview to drill a
# specific weak area. Same rule as everywhere else in this course: no model answers are ever
# shown here — check `solutions/question_bank_answers.json` afterward.

# %% [markdown]
# ## Setup

# %%
import json
import sys
import time
from pathlib import Path

from IPython.core.error import StdinNotImplementedError

_repo_root = Path.cwd()
if not (_repo_root / "agentlib").is_dir():
    _repo_root = _repo_root.parent
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

QUESTION_BANK_PATH = _repo_root / "interview_prep" / "question_bank.json"

with open(QUESTION_BANK_PATH) as f:
    question_bank = json.load(f)

print(f"Loaded {len(question_bank)} questions across 9 chapters.")
# Out:
# Loaded 93 questions across 9 chapters.

# %%
def get_answer(prompt: str) -> str:
    '''Same headless-safe input() wrapper as mock_interview.ipynb -- catches both EOFError
    (plain Python, closed stdin) and IPython's StdinNotImplementedError (the ZMQ kernel used
    by nbconvert/nbmake, whose frontend doesn't implement stdin requests at all), so this
    notebook executes cleanly with zero errors under a headless test runner while still
    behaving like a normal input() prompt when run interactively.'''
    print(prompt)
    try:
        return input("Your answer: ")
    except (EOFError, StdinNotImplementedError):
        print("(no interactive input available in this run -- using a placeholder answer "
              "so the rest of this cell's logic still executes for real)")
        return "(placeholder answer -- no interactive input available)"


def keyword_feedback(answer_text: str, key_concepts: list) -> str:
    '''A rough, directional signal only -- not a grade.'''
    answer_lower = answer_text.lower()
    mentioned = [c for c in key_concepts if c.lower() in answer_lower]
    missed = [c for c in key_concepts if c.lower() not in answer_lower]
    lines = ["(rough keyword signal, not a grade -- see the solutions file for what actually matters)"]
    if mentioned:
        lines.append(f"  you mentioned: {', '.join(mentioned)}")
    if missed:
        lines.append(f"  you didn't mention: {', '.join(missed)}")
    return "\n".join(lines)

# %% [markdown]
# ## Pick a chapter to drill
#
# Set `CHAPTER` below to a number 1-9. Every question tagged with that chapter runs, in the
# order it appears in `question_bank.json` — no sampling, no randomization.

# %%
CHAPTER_NAMES = {
    1: "Fundamentals of AI Agents", 2: "Agent Control Flow", 3: "RAG and Retrieval Evaluation",
    4: "Production Reliability", 5: "Cost, Performance, and Model Selection",
    6: "Security and Safeguards", 7: "Tool Integration", 8: "System Design and Engineering Judgment",
    9: "LLMOps and Deployment",
}

CHAPTER = 6  # change this to drill a different chapter

drill_questions = [q for q in question_bank if q["chapter"] == CHAPTER]
print(f"Chapter {CHAPTER}: {CHAPTER_NAMES[CHAPTER]}")
print(f"{len(drill_questions)} questions queued, in bank order (no randomization).")
# Out:
# Chapter 6: Security and Safeguards
# 9 questions queued, in bank order (no randomization).

# %%
def run_drill(questions: list) -> list:
    asked_ids = []
    for i, q in enumerate(questions, start=1):
        print(f"\n{'-' * 70}")
        print(f"Drill {i}/{len(questions)}  --  {q['difficulty']}, {q['category']}, format: {q['format']}")
        print("-" * 70)

        start = time.time()
        answer = get_answer(q["scenario"])
        elapsed = time.time() - start
        print(f"\n(elapsed: {elapsed:.0f}s -- soft timer, nothing was cut off)")

        print(keyword_feedback(answer, q["key_concepts"]))
        print(f"\nFollow-up: {q['follow_up']}")

        if q.get("grounded_in_real_incident"):
            print(f"(this scenario is grounded in a real public incident -- see "
                  f"question_bank.json's source_note for id {q['id']} if you want to read more)")

        asked_ids.append(q["id"])
    return asked_ids


asked = run_drill(drill_questions)
# Out:
# ----------------------------------------------------------------------
# Drill 1/9  --  mid, Prompt injection and safeguards, format: scenario_first
# ----------------------------------------------------------------------
# A prompt causes your AI agent to expose confidential data.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: instruction/data separation, output filtering, least privilege, defense in depth
#
# Follow-up: What production safeguards should have prevented this?
#
# ----------------------------------------------------------------------
# Drill 2/9  --  senior, Prompt injection and safeguards, format: scenario_first
# ----------------------------------------------------------------------
# In December 2023, a customer testing a Chevrolet dealership's AI-powered chatbot used prompt injection to get it to "agree" that it would sell him a vehicle for one dollar, framed as a legally binding offer — the exchange went viral before the dealership shut the bot down.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: direct prompt injection, tool/action scoping, output constraints, no binding commitments from an unguarded LLM
#
# Follow-up: What specific technical safeguard (not "be more careful") would have prevented the bot from ever producing that kind of output?
# (this scenario is grounded in a real public incident -- see question_bank.json's source_note for id security-002 if you want to read more)
#
# ----------------------------------------------------------------------
# Drill 3/9  --  mid, Prompt injection and safeguards, format: question_first
# ----------------------------------------------------------------------
# A support agent reads incoming customer tickets and has a tool that can issue refunds.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: policy check independent of decision path, defense in depth, least privilege
#
# Follow-up: What's the single most important thing to check on every refund tool call, regardless of how the agent decided to make it?
#
# ----------------------------------------------------------------------
# Drill 4/9  --  senior, Prompt injection and safeguards, format: slack_message
# ----------------------------------------------------------------------
# Slack, #security: "we added a system prompt line that says 'never reveal internal notes' but a user got the model to print them anyway, how"
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: mixed instruction/data channel, no structural separation in a prompt, output filtering as a backstop
#
# Follow-up: Why doesn't a strongly-worded instruction reliably stop this?
#
# ----------------------------------------------------------------------
# Drill 5/9  --  mid, Prompt injection and safeguards, format: stakeholder_quote
# ----------------------------------------------------------------------
# "Can't we just tell the model in the prompt to never do anything harmful, and call it solved?" a less-technical stakeholder asks.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: defense in depth, no single mitigation is sufficient, instruction-following is not a hard guarantee
#
# Follow-up: How do you explain why that's not sufficient, without being dismissive?
#
# ----------------------------------------------------------------------
# Drill 6/9  --  senior, Prompt injection and safeguards, format: scenario_first
# ----------------------------------------------------------------------
# An agent has a single general-purpose `run_db_command(sql)` tool instead of several narrow, task-specific tools.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: least privilege, blast radius, tool scoping
#
# Follow-up: How does that change the consequences of a successful prompt injection, even if the injection itself isn't preventable?
#
# ----------------------------------------------------------------------
# Drill 7/9  --  mid, Prompt injection and safeguards, format: question_first
# ----------------------------------------------------------------------
# You're asked to define, precisely, the difference between direct and indirect prompt injection.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: direct vs. indirect prompt injection, untrusted retrieved content
#
# Follow-up: What's the difference, and why does it matter more once an agent has tools?
#
# ----------------------------------------------------------------------
# Drill 8/9  --  junior, Prompt injection and safeguards, format: scenario_first
# ----------------------------------------------------------------------
# A teammate suggests output filtering alone (scanning every response for secret-shaped patterns before returning it) is a sufficient defense against data leaks.
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: output filtering as a last-resort net, not the only layer, secrets shouldn't be reachable in context at all
#
# Follow-up: What's the gap in relying on that alone?
#
# ----------------------------------------------------------------------
# Drill 9/9  --  senior, Prompt injection and safeguards, format: slack_message
# ----------------------------------------------------------------------
# Slack, #eng: "security review flagged that our system prompt includes an internal API key as 'context the model needs' — is that actually a problem if we also tell it never to reveal it"
# (no interactive input available in this run -- using a placeholder answer so the rest of this cell's logic still executes for real)
#
# (elapsed: 0s -- soft timer, nothing was cut off)
# (rough keyword signal, not a grade -- see the solutions file for what actually matters)
#   you didn't mention: secrets don't belong in a prompt at all, code/config boundary vs. model context, instruction is not a guarantee
#
# Follow-up: How do you respond?

# %% [markdown]
# ## Drill summary
#
# As always: no model answers are shown here. Review against
# `solutions/question_bank_answers.json` after you've finished.

# %%
print(f"Drill complete -- Chapter {CHAPTER}: {CHAPTER_NAMES[CHAPTER]}")
print(f"{len(asked)} question(s) covered:")
for qid in asked:
    print(f"  - {qid}")
print(f"\nReview your answers against: solutions/question_bank_answers.json")
# Out:
# Drill complete -- Chapter 6: Security and Safeguards
# 9 question(s) covered:
#   - security-001
#   - security-002
#   - security-003
#   - security-004
#   - security-005
#   - security-006
#   - security-007
#   - security-008
#   - security-009
#
# Review your answers against: solutions/question_bank_answers.json
