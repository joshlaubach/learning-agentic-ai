# %% [markdown]
# # Per-Chapter Drills

# %% [markdown]
# ## Under construction
#
# This notebook is a placeholder created during the repository scaffold (Unit 1 of the build — see `PROGRESS.md`). Real content — concept, build, break-it, and interview-prep sections — will be added in **Unit 11** of the build (see `PROGRESS.md`), alongside `question_bank.json` and `solutions/question_bank_answers.json`.

# %%
# Placeholder cell so this stub notebook actually executes end-to-end.
# Real chapter content replaces this cell when this notebook is built out.
print("Placeholder for: Per-Chapter Drills")
